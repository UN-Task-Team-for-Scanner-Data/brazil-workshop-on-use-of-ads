# %% [markdown]
# <a href="https://colab.research.google.com/github/UN-Task-Team-for-Scanner-Data/brazil-workshop-on-use-of-ads/blob/multilateral/Index_Calculation_Exercises_Solutions_in_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multilateral Index Calculation in R - Exercises
#
# In order to do the exercises we need to load the packages and prepare the dataset first.

# %%
# Install required packages
install.packages(c('PriceIndices', 'IndexNumR', 'plotly'), repos='https://cran.r-project.org')

# Set the options such that unnessecary warnings are muted
knitr::opts_chunk$set(echo = TRUE)
options(dplyr.summarise.inform = FALSE)
options(dplyr.mutate.inform = FALSE)
options(tidyverse.quiet = TRUE)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘stringdist’, ‘lpSolve’, ‘checkmate’, ‘reshape’, ‘reclin2’, ‘strex’, ‘lazyeval’, ‘crosstalk’

# %% [markdown]
# It is possible to do the exercises using the following packages. However, you can load and use other packages if you want.
#
# > Add blockquote

# %%
library(PriceIndices) # for price index calculations
library(IndexNumR)    # for price index calculations
library(tidyverse)    # for data analysis
library(plotly)       # for interactive graphics
library(ggplot2)      # for graphics
# Out:
# Attaching package: ‘IndexNumR’
#
#
# The following object is masked from ‘package:PriceIndices’:
#
#     elasticity
#
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %% [markdown]
# ## Dataset
#
# We use the same data as yesterday from the set of food prices in Italian supermarkets provided by Banca d'Italia, Università Campus Bio-Medico and Università degli Studi della Tuscia. The complete dataset is available [here](https://zenodo.org/records/14927602). We aggregated the data by month and added artificial quantities.

# %%
data <- read.csv("https://raw.githubusercontent.com/UN-Task-Team-for-Scanner-Data/alternative-data-sources-price-statistics/refs/heads/main/data/monthly_avg_price_with_qty.csv")

# Filter for bananas in Store 3
data <- data %>% filter(COICOP5 %in% "Salad" & store_id %in% 3) %>%
         mutate(product_id = as.numeric(factor(product)),
                volume = price * quantity,
                total_quantity = NULL, quantity_share = NULL)

# Extract package size from product description and convert to kg
data <- data %>% mutate(size = case_when(
  str_sub(product, -2, -1) == "kg" ~ as.numeric(str_extract(product, "(\\d+).(\\d+)")),
  str_sub(product, -2, -1) == "gr" ~ as.numeric(str_extract(product, "(\\d+).(\\d+)")) / 1000,
  str_sub(product, -2, -1) == "pz" ~ as.numeric(str_extract(product, "(\\d+).(\\d+)")) * .18))

# Adjust price to "per kg" and quantity to "kg sold"
data <- data %>% mutate(price = price / size, quantity = quantity * size)

# %% [markdown]
# # Index calculation
#
# The exercise can be done using either the `IndexNumR` or `PriceIndices` package. Choose the one you prefer.

# %% [markdown]
# **Exercise 1**
# Format the dataset such that it works as input for one of the packages and name the data.frame `input`.

# %%
# Input for PriceIndices functions
input_pi <- data_preparing(data,
               time       = "month_year", # convert the period into date format and rename the column and
               prices     = "price",
               quantities = "quantity",
               prodID     = "product_id")
head(input_pi)

# Input for IndexNumR functions
input_in <- data %>% mutate(pervar = monthIndex(ym(data$month_year)))
head(input_in)

# A data.frame that includes all columns
input <-  cbind(input_in, input_pi)


input %>% filter(product_id %in% c(1,9,11,12,15))
# Out:
#   time       prices   quantities prodID
# 1 2022-12-01 7.265010 31.13706   1
# 2 2020-12-01 8.062500 19.39783   2
# 3 2021-01-01 8.304435 19.45712   2
# 4 2021-02-01 8.062500 19.29304   2
# 5 2021-03-01 8.062500 21.15349   2
# 6 2021-04-01 8.062500 16.70443   2
#   month_year product                                                   store_id
# 1 2022-12    bonduelle carta delle insalate ricetta croccante 230.0 gr 3
# 2 2020-12    cuore lattuga 160.0 gr                                    3
# 3 2021-01    cuore lattuga 160.0 gr                                    3
# 4 2021-02    cuore lattuga 160.0 gr                                    3
# 5 2021-03    cuore lattuga 160.0 gr                                    3
# 6 2021-04    cuore lattuga 160.0 gr                                    3
#   COICOP5 COICOP4   price    quantity product_id volume   size pervar
# 1 Salad   Vegetable 7.265010 31.13706 1          226.2110 0.23 25
# 2 Salad   Vegetable 8.062500 19.39783 2          156.3950 0.16  1
# 3 Salad   Vegetable 8.304435 19.45712 2          161.5804 0.16  2
# 4 Salad   Vegetable 8.062500 19.29304 2          155.5501 0.16  3
# 5 Salad   Vegetable 8.062500 21.15349 2          170.5500 0.16  4
# 6 Salad   Vegetable 8.062500 16.70443 2          134.6795 0.16  5
#    month_year product
# 1  2022-12    bonduelle carta delle insalate ricetta croccante 230.0 gr
# 2  2020-12    rucola 125.0 gr
# 3  2021-01    rucola 125.0 gr
# 4  2021-02    rucola 125.0 gr
# 5  2021-03    rucola 125.0 gr
# 6  2021-04    rucola 125.0 gr
# 7  2021-05    rucola 125.0 gr
# 8  2021-06    rucola 125.0 gr
# 9  2021-07    rucola 125.0 gr
# 10 2021-08    rucola 125.0 gr
# 11 2021-09    rucola 125.0 gr
# 12 2021-10    rucola 125.0 gr
# 13 2021-11    rucola 125.0 gr
# 14 2021-12    rucola 125.0 gr
# 15 2022-01    rucola 125.0 gr
# 16 2022-02    rucola 125.0 gr
# 17 2022-03    rucola 125.0 gr
# 18 2022-04    rucola 125.0 gr
# 19 2022-05    rucola 125.0 gr
# 20 2022-06    rucola 125.0 gr
# 21 2022-07    rucola 125.0 gr
# 22 2022-08    rucola 125.0 gr
# 23 2022-09    rucola 125.0 gr
# 24 2022-10    rucola 125.0 gr
# 25 2022-11    rucola 125.0 gr
# 26 2022-10    rucola igp bonduelle 90.0 gr
# 27 2022-11    rucola igp bonduelle 90.0 gr
# 28 2022-12    rucola igp bonduelle 90.0 gr
# 29 2023-03    rucola igp bonduelle 90.0 gr
# 30 2023-04    rucola igp bonduelle 90.0 gr
# ⋮  ⋮          ⋮
# 47 2022-04    rucola orti laziali vasc 100.0 gr
# 48 2022-05    rucola orti laziali vasc 100.0 gr
# 49 2022-06    rucola orti laziali vasc 100.0 gr
# 50 2022-07    rucola orti laziali vasc 100.0 gr
# 51 2022-08    rucola orti laziali vasc 100.0 gr
# 52 2022-09    rucola orti laziali vasc 100.0 gr
# 53 2022-10    rucola orti laziali vasc 100.0 gr
# 54 2022-11    rucola orti laziali vasc 100.0 gr
# 55 2022-12    rucola orti laziali vasc 100.0 gr
# 56 2021-03    valeriana qual 80.0 gr
# 57 2021-04    valeriana qual 80.0 gr
# 58 2021-05    valeriana qual 80.0 gr
# 59 2021-06    valeriana qual 80.0 gr
# 60 2021-07    valeriana qual 80.0 gr
# 61 2021-08    valeriana qual 80.0 gr
# 62 2021-09    valeriana qual 80.0 gr
# 63 2021-10    valeriana qual 80.0 gr
# 64 2021-11    valeriana qual 80.0 gr
# 65 2021-12    valeriana qual 80.0 gr
# 66 2022-01    valeriana qual 80.0 gr
# 67 2022-02    valeriana qual 80.0 gr
# 68 2022-03    valeriana qual 80.0 gr
# 69 2022-04    valeriana qual 80.0 gr
# 70 2022-05    valeriana qual 80.0 gr
# 71 2022-06    valeriana qual 80.0 gr
# 72 2022-07    valeriana qual 80.0 gr
# 73 2022-08    valeriana qual 80.0 gr
# 74 2022-09    valeriana qual 80.0 gr
# 75 2022-10    valeriana qual 80.0 gr
# 76 2022-11    valeriana qual 80.0 gr
#    store_id COICOP5 COICOP4   price    quantity  product_id volume    size
# 1  3        Salad   Vegetable  7.26501 31.137055  1         226.21103 0.230
# 2  3        Salad   Vegetable 10.32000 14.712067  9         151.82853 0.125
# 3  3        Salad   Vegetable 10.62968 15.905984  9         169.07548 0.125
# 4  3        Salad   Vegetable 10.32000 13.904750  9         143.49702 0.125
# 5  3        Salad   Vegetable 10.32000 16.181070  9         166.98865 0.125
# 6  3        Salad   Vegetable 10.32000 15.769240  9         162.73856 0.125
# 7  3        Salad   Vegetable 11.92000 15.244529  9         181.71478 0.125
# 8  3        Salad   Vegetable 11.92000 12.488624  9         148.86439 0.125
# 9  3        Salad   Vegetable 11.92000 14.830675  9         176.78165 0.125
# 10 3        Salad   Vegetable 11.92000 14.857105  9         177.09670 0.125
# 11 3        Salad   Vegetable 11.92000 13.731401  9         163.67830 0.125
# 12 3        Salad   Vegetable 11.92000 16.471513  9         196.34044 0.125
# 13 3        Salad   Vegetable 11.92000 13.121024  9         156.40260 0.125
# 14 3        Salad   Vegetable 11.92000 14.920724  9         177.85503 0.125
# 15 3        Salad   Vegetable 11.92000 15.194339  9         181.11652 0.125
# 16 3        Salad   Vegetable 11.92000 16.020309  9         190.96209 0.125
# 17 3        Salad   Vegetable 11.92000 15.553445  9         185.39707 0.125
# 18 3        Salad   Vegetable 11.92000 15.256813  9         181.86121 0.125
# 19 3        Salad   Vegetable 11.92000 15.871107  9         189.18359 0.125
# 20 3        Salad   Vegetable 11.92000 15.577225  9         185.68052 0.125
# 21 3        Salad   Vegetable 11.03111 14.800999  9         163.27146 0.125
# 22 3        Salad   Vegetable 11.92000 16.193440  9         193.02581 0.125
# 23 3        Salad   Vegetable 10.05333 14.172300  9         142.47886 0.125
# **Exercise 2**
# Calculate a GEKS-Index using the Fisher formula from december 2020 to december 2022 without splicing.
# # *Hint: The GEKS-Fisher method is called "geks" in the PriceIndices package*

# %%
# GEKS-Fisher with PriceIndices::price_indice
geks_pi <- price_indices(input,
                         start="2020-12",
                         end="2022-12",
                         formula="geks",
                         window= 25,
                         interval=TRUE
)


# GEKS-Fisher with IndexNumR::GEKSIndex
geks_in <- GEKSIndex(input %>% filter(pervar <= 25),
                     pvar = "price",
                     qvar = "quantity",
                     pervar = "pervar",
                     prodID = "product_id",
                     indexMethod = "fisher",
                     window = 25,
)

# Both packages in one data.frame
data.frame(month = geks_pi$time,
           indexNumR = geks_in,
           PriceIndices = geks_pi$geks)
# Out:
#    month   indexNumR PriceIndices
# 1  2020-12 1.000000  1.000000
# 2  2021-01 1.116764  1.116764
# 3  2021-02 1.106457  1.106457
# 4  2021-03 1.043450  1.043450
# 5  2021-04 1.063910  1.063910
# 6  2021-05 1.137317  1.137317
# 7  2021-06 1.124290  1.124290
# 8  2021-07 1.123579  1.123579
# 9  2021-08 1.124631  1.124631
# 10 2021-09 1.042347  1.042347
# 11 2021-10 1.101737  1.101737
# 12 2021-11 1.128024  1.128024
# 13 2021-12 1.128591  1.128591
# 14 2022-01 1.125366  1.125366
# 15 2022-02 1.104308  1.104308
# 16 2022-03 1.136841  1.136841
# 17 2022-04 1.136055  1.136055
# 18 2022-05 1.137076  1.137076
# 19 2022-06 1.148578  1.148578
# 20 2022-07 1.091641  1.091641
# 21 2022-08 1.129602  1.129602
# 22 2022-09 1.044392  1.044392
# 23 2022-10 1.112807  1.112807
# 24 2022-11 1.123980  1.123980
# 25 2022-12 1.109119  1.109119

# %% [markdown]
# **Exercise 3**
# Now calculate spliced GEKS-Fisher indices. Use a window splice with a window length of 13 months as well as a movement splice with a window length of 4 months. Compare all three indices.

# %%
# Window splice with PriceIndices::price_indice
geks_window_pi <- price_indices(input,
                             start = "2020-12",
                             end = "2022-12",
                             formula = "geks_splice",
                             window = 4,
                             interval =T,
                             splice = "window"
)

# Window splice with IndexNumR::GEKSIndex
geks_window_in <- GEKSIndex(input %>% filter(pervar <= 25),
                            pvar = "price",
                            qvar = "quantity",
                            pervar = "pervar",
                            prodID = "product_id",
                            indexMethod = "fisher",
                            sample = "matched",
                            window = 4,
                            splice = "window"
)

# Movement splice with PriceIndices::price_indice
geks_movement_pi <- price_indices(input,
                               start="2020-12",
                               end="2022-12",
                               formula="geks_splice",
                               window= 4,
                               interval=TRUE,
                               splice = "movement"
)

# Movement splice with IndexNumR::GEKSIndex
geks_movement_in <- GEKSIndex(input %>% filter(pervar <= 25),
            pvar = "price",
            qvar = "quantity",
            pervar = "pervar",
            prodID = "product_id",
            indexMethod = "fisher",
            sample = "matched",
            window = 4,
            splice = "hasp", # "window", "movement", "half", "mean", "fbew", "fbmw", "wisp", "hasp" or mean_pub" are the options
            imputePrices = NULL
)


# The results in one data.frame
comparison <- data.frame(month = geks_pi$time,
                      "25_month_window" = geks_pi$geks,
                      "13_month_window_splice" = geks_window_pi$geks_splice,
                      "4_month_movement_splice" = geks_movement_in
                      )

# Visualising the results
pivot_longer(comparison, cols = -1, names_to = "splice", values_to = "index") %>%
  ggplot(., aes(x = month, y = index, group = splice, color = splice)) + geom_line()
# Out:
# plot without title

# %% [markdown]
# **Exercise 4**
# Calculate an index using the weighted time product dummy or the geary-khamis method. From december 2020 to december 2022 and compare it to the geks index.

# %%
# WTPD with PriceIndices::price_indice
wtpd_pi <- price_indices(input, start="2020-12", end="2022-12",
  formula="tpd", window=25, interval=TRUE)

# WTPD with IndexNumR::WPTDIndex
wtpd_in <- WTPDIndex(input %>% filter(pervar <= 25),
                     pvar = "price",
                     qvar = "quantity",
                     pervar = "pervar",
                     prodID = "product_id",
                     window = 25
          )

# Geary-Khamis with PriceIndices::price_indice
gk_pi <- price_indices(input, start="2020-12", end="2022-12",
  formula="gk", window=25, interval=TRUE)

# Geary-Khamis with IndexNumR::WPTDIndex
gk_in <- GKIndex(input %>% filter(pervar <= 25),
                     pvar = "price",
                     qvar = "quantity",
                     pervar = "pervar",
                     prodID = "product_id",
                     window = 25
          )

# The results in one data.frame
comparison <- data.frame(month = geks_pi$time,
                      "GEKS" = geks_pi$geks,
                      "WTPD" = wtpd_in,
                      "Geary-Khamis" = gk_pi$gk
                      )

# Visualising the results
pivot_longer(comparison, cols = -1, names_to = "splice", values_to = "index") %>%
  ggplot(., aes(x = month, y = index, group = splice, color = splice)) + geom_line()
# Out:
# plot without title

# %% [markdown]
# **Bonus**
# Calculate a GEKS-Jevons index and compare it to a chain linked bilateral Jevons index.

# %%
# WTPD with PriceIndices::price_indice
jevons_pi <- price_indices(input, start="2020-12", end="2022-12",
  formula="chjevons", interval=TRUE)

# WTPD with IndexNumR::WPTDIndex
jevons_in <- priceIndex(input %>% filter(pervar <= 25),
                     pvar = "price",
                     qvar = "quantity",
                     pervar = "pervar",
                     prodID = "product_id",
                     indexMethod = "jevons",
                     output = "chained"
          )

# GEKS-Jevons with PriceIndices::price_indice
geks_jevons_pi <- price_indices(input, start="2020-12", end="2022-12",
  formula="geksj", window=25, interval=TRUE)

# GEKS-Jevons with IndexNumR::WPTDIndex
geks_jevons_in <- GEKSIndex(input %>% filter(pervar <= 25),
                     pvar = "price",
                     qvar = "quantity",
                     pervar = "pervar",
                     prodID = "product_id",
                     indexMethod = "jevons",
          )

# The results in one data.frame
comparison <- data.frame(month = jevons_pi$time,
                      "GEKS-Jevons" = geks_jevons_pi$geksj,
                      "Jevons" = jevons_in
                      )

# Visualising the results
pivot_longer(comparison, cols = -1, names_to = "splice", values_to = "index") %>%
  ggplot(., aes(x = month, y = index, group = splice, color = splice)) + geom_line()
# Out:
# plot without title
